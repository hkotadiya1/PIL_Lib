# %% [markdown]
# ## PIL Library

# %%
from PIL import Image

# %%
image = Image.open("Duck.png") #Open image from local folder

# %%
image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=415x612 at 0x1947F217160>

# %%
image.size # size of image
# Out:
# (415, 612)

# %%
image.format #format of image
# Out:
# 'JPEG'

# %%
image.mode # red blue green
# Out:
# 'RGB'

# %%
dir(image) # methods and functions
# Out:
# ['_ArrayData',
#  '_Image__transformer',
#  '__array__',
#  '__class__',
#  '__copy__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_category',
#  '_close_exclusive_fp_after_loading',
#  '_copy',
#  '_crop',
#  '_dump',
#  '_ensure_mutable',
#  '_exclusive_fp',
#  '_exif',
#  '_expand',
#  '_get_safe_box',
#  '_getexif',
#  '_getmp',
#  '_getxmp',
#  '_min_frame',
#  '_new',
#  '_open',
#  '_repr_png_',
#  '_seek_check',
#  '_size',
#  'alpha_composite',
#  'app',
#  'applist',
#  'bits',
#  'close',
#  'convert',
#  'copy',
#  'crop',
# ...

# %%
from PIL import ImageFilter

# %%
filtered_img = image.filter(ImageFilter.BLUR)# Filter the image
#filtered_img = image.filter(ImageFilter.SMOOTH)
#filtered_img = image.filter(ImageFilter.SHARPEN)

# %%
filtered_img #BLUR image
# Out:
# <PIL.Image.Image image mode=RGB size=415x612 at 0x1947EA025E0>

# %%
filtered_img.save("blur.png","png")

# %%
img1 = image.convert("L")

# %%
img1
#img1.show()
# Out:
# <PIL.Image.Image image mode=L size=415x612 at 0x1947F34D2E0>

# %%
img2 = image.convert("1")

# %%
img2
# Out:
# <PIL.Image.Image image mode=1 size=415x612 at 0x1947EB84100>

# %%
rotate = image.rotate(90) #rotate image

# %%
rotate
# Out:
# <PIL.Image.Image image mode=RGB size=415x612 at 0x1947F4ECC70>

# %%
new=(400,400)
resize = image.resize(new)

# %%
resize
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x1947E9A5CA0>

# %%
new1=(100,100,300,300)
crop = image.crop(new1)

# %%
crop
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x1947F4C9880>

# %%
thumbnail = image.thumbnail((100,100))

# %%
image.save("thumbnail.png","png") # for thumbnail

# %%
print(image.size)
# Out:
# (68, 100)
